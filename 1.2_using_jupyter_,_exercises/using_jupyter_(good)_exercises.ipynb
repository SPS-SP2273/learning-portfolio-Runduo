# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Fundamentals (Good) Exercises</span></div>

# %%
while True:
    print('*', end='')
# Out:
# **************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************
# ...

# %%
print = 'PRINT'

# %%
print('Hello World')
# Out:
# Hello World

# %%
squares = [i**2 for i in range(10)]

# %%
print([i**2 for i in range(10)])
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]

# %%
squares = [i**2 for i in range(10)]

# %%
# %timeit print([i**2 for i in range(10)])
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]
# ...

# %%
# %%timeit
squares = list()
for i in range(10):
    squares.append(i**2)
# Out:
# 546 ns ± 51.9 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# The value of the mean time required to run the second code for 7 runs for 1 million loops is lower by around 1000 times (3 orders of magnitude) in terms of raw value relative to the first code, which is ran for 7 runs for 10000 loops. In terms of uncertainty related to the measurement, the percentage uncertainty in the first code is way higher at around 50% where as the second code has a percentage uncertainty at around 10%.
#
# The deviation in the mean values is logical as the first loop is ran for 1 million loops whereas the second loop is ran for 10000 loops. Assuming constant rate, the deviation would be around 10^6/10^4=10^2, therefore the first code would take around 100 to 1000 more times longer to finish.
#
# In the first code, it is reported that the slowest run took 17.02 times longer than the fastest run, contributing to its relatively higher percentage uncertainty and potentially suggesting that an intermediate is cached.

# %%
squares = [i**2 for i in range(10)]
